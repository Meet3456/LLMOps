# %%
print("Hello World")
# Out:
# Hello World

# %%
# !pip show camelot

# %%
# !pip install -qU camelot-py[base] matplotlib

# %%
import camelot

# %%
tables = camelot.read_pdf('/home/meet/Downloads/sample 1.pdf', pages="all", flavor='lattice')
tables
# Out:
# <TableList n=5>

# %%
print(len(tables))
# Out:
# 5

# %%
tables[4]
# Out:
# <Table shape=(18, 7)>

# %%
print(tables[4].parsing_report)
# Out:
# {'accuracy': 93.42, 'whitespace': 27.78, 'order': 1, 'page': 5}

# %%
table_to_df = tables[4].df
table_to_df
# Out:
#                0                                  1  \
# 0       Txn Date                        Value\nDate
# 1    20 Jul 2021        20 Jul 2021 BY TRANSFER-INB
# 2    20 Jul 2021   20 Jul 2021 by debit card-OTHPOS
# 3    23 Jul 2021  23 Jul 2021 WITHDRAWAL TRANSFER--
# 4    23 Jul 2021          23 Jul 2021 BULK POSTING-
# 5    31 Jul 2021       31 Jul 2021 ATM WDL-ATM CASH
# 6     2 Aug 2021            2 Aug 2021 BY TRANSFER-
# 7     2 Aug 2021         2 Aug 2021 TO TRANSFER-INB
# 8     8 Aug 2021      8 Aug 2021 ATM WDL-ATM CASH 4
# 9   12 Aug\n2021                       12 Aug\n2021
# 10  16 Aug\n2021                       16 Aug\n2021
# 11  23 Aug\n2021                       23 Aug\n2021
# 12  27 Aug\n2021                       27 Aug\n2021
# 13  30 Aug\n2021                       30 Aug\n2021
# 14  30 Aug\n2021                       30 Aug\n2021
# 15    1 Sep 2021            1 Sep 2021 BY TRANSFER-
# 16    1 Sep 2021         1 Sep 2021 TO TRANSFER-INB
# ...
